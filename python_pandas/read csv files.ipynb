# %%
import pandas as pd

df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv')
df
# Out:
#   stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv',skiprows=1)
#df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv',header=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#if you dont have any header but you know the headers
df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv')
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv',header=None,names=['tickers','eps','revenue','price','people'
])
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#if you want to read just some rows of csv
df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv',nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
#solving problems with NAN
df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv',na_values=['not available','n.a.'])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
#if you want to turn just -1 in one revenue column to nan use dictanary
df=pd.read_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.csv',na_values={'eps':['not available','n.a.'],
                                                                                                          'revenue':['not available','n.a.',-1],'price':['not available','n.a.'],
                                                                                                         'people':['not available','n.a.']})
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
#writing to csv
df.to_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/new_stock_data.csv')

# %%
#without index
df.to_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/new_stock_data.csv',index=False)

# %%
#exporting some columns
df.to_csv('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/new_stock_data.csv',index=False,columns=['tickets','eps','revenue'])

# %%
import openpyxl

# %%
df=pd.read_excel('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.xlsx')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def convertor_nan(cell):
    if cell=='n.a.':
        return 'sam smith'
    return cell
df=pd.read_excel('D:/data scince/practice/py-master/pandas/4_read_write_to_excel/stock_data.xlsx',converters={'people':convertor_nan})
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65      sam smith
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df.to_excel('')

# %%
#writing dataframes you made here in python
with pd.ExcelWriter('stocks_weather.xlsx')as writer
df.to_excel(writer,sheet_name=stocks)

# %% [markdown]
# ***OSMnx: Python for Street Networks***
#
# OSMnx is a Python package to retrieve, model, analyze, and visualize street networks from OpenStreetMap.

# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Tallin, Estonia'))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# **Get administrative place boundaries and shapefiles**

# %%
import osmnx as ox
city = ox.geocode_to_gdf('Tallin, Estonia')
ax = ox.project_gdf(city).plot()
_ = ax.axis('off')

# %%
places = ox.geocode_to_gdf(['Botswana', 'Zambia', 'Zimbabwe'])
places = ox.project_gdf(places)
ax = places.plot()
_ = ax.axis('off')

# %% [markdown]
# **Download and model street networks**

# %%
G = ox.graph_from_bbox(37.79, 37.78, -122.41, -122.43, network_type='drive')
G_projected = ox.project_graph(G)
ox.plot_graph(G_projected)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# **street network from lat-long point**

# %%
G = ox.graph_from_point((37.79, -122.41), dist=750, network_type='all')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# **street network from address**

# %%
G = ox.graph_from_address('Raatuse, Tartu, Estonia', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
#  **street network from polygon**

# %%
#G = ox.graph_from_polygon(mission_shape, network_type='drive')
#ox.plot_graph(G)

# %% [markdown]
# **street network from place name**

# %%
G = ox.graph_from_place('Tartu, Estonia', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
places = ['Los Altos, California, USA',
          {'city':'Los Altos Hills', 'state':'California'},
          'Loyola, California']
G = ox.graph_from_place(places, network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# **Analyze street networks**

# %%
G = ox.graph_from_place('Santa Monica, California', network_type='walk')
basic_stats = ox.basic_stats(G)
print(basic_stats['circuity_avg'])
extended_stats = ox.extended_stats(G, bc=True)
print(extended_stats['betweenness_centrality_avg'])
# Out:
# 1.050392960453962
# 0.008876793192477568

# %%
G = ox.graph_from_place('Piedmont, CA, USA', network_type='drive')
route = nx.shortest_path(G, orig, dest)
fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='k')
